# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\cfc\anaconda3\lib\site-packages (0.15.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\cfc\anaconda3\lib\site-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\cfc\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\cfc\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\cfc\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cfc\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cfc\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cfc\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cfc\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cfc\anaconda3\lib\site-packages (from requests->folium) (2023.11.17)

# %%
import folium

# Crear un objeto de mapa centrado en una ubicación inicial
mapa = folium.Map(location=[20.0, 0.0], zoom_start=2)

# Lista de puntos geográficos (latitud, longitud)
puntos = [
    {"nombre": "Punto 1", "coordenadas": [34.0522, -118.2437]},  # Los Ángeles
    {"nombre": "Punto 2", "coordenadas": [40.7128, -74.0060]},   # Nueva York
    {"nombre": "Punto 3", "coordenadas": [51.5074, -0.1278]},    # Londres
    {"nombre": "Punto 4", "coordenadas": [35.6895, 139.6917]},   # Tokio
    {"nombre": "Punto 5", "coordenadas": [-33.8688, 151.2093]},  # Sídney
]

# Añadir puntos al mapa
for punto in puntos:
    folium.Marker(
        location=punto["coordenadas"],
        popup=punto["nombre"],
        icon=folium.Icon(icon="info-sign")
    ).add_to(mapa)

# Guardar el mapa en un archivo HTML
mapa.save("mapa.html")

# Mostrar el mapa en el entorno de Google Colab
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a393f5d9b982904589f5c176aa0b7816 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a393f5d9b982904589f5c176aa0b7816&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a393f5d9b982904589f5c176aa0b7816 = L.map(
#                 &quot;map_a393f5d9b982904589f5c176aa0b7816&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93f68b33ab2451a384dc120c922126e0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_93f68b33ab2451a384dc120c922126e0.addTo(map_a393f5d9b982904589f5c176aa0b7816);
#
#             var marker_33c7dba860e8b47028e964864fb46281 = L.marker(
#                 [34.0522, -118.2437],
#                 {}
#             ).addTo(map_a393f5d9b982904589f5c176aa0b7816);
#
#
#             var icon_8b92cdcb5307648b34a17e38f06497bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_33c7dba860e8b47028e964864fb46281.setIcon(icon_8b92cdcb5307648b34a17e38f06497bd);
#
#
#         var popup_024a76446bfe3ad646a96d7b3c8d7088 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07d2085746771661e243fc5116018830 = $(`&lt;div id=&quot;html_07d2085746771661e243fc5116018830&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto 1&lt;/div&gt;`)[0];
#                 popup_024a76446bfe3ad646a96d7b3c8d7088.setContent(html_07d2085746771661e243fc5116018830);
#
#
#
#         marker_33c7dba860e8b47028e964864fb46281.bindPopup(popup_024a76446bfe3ad646a96d7b3c8d7088)
#         ;
#
#
#
#
#             var marker_e6aa3be03e14cfa61bb4773a5fd07a4c = L.marker(
#                 [40.7128, -74.006],
#                 {}
#             ).addTo(map_a393f5d9b982904589f5c176aa0b7816);
#
#
#             var icon_00a1fc0b29f1acc96f621ad404dff9fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e6aa3be03e14cfa61bb4773a5fd07a4c.setIcon(icon_00a1fc0b29f1acc96f621ad404dff9fa);
#
#
#         var popup_3920a2f7d339de6ab9ad9f5808f27182 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfa88793c74dc2851a85d2d6101a5a11 = $(`&lt;div id=&quot;html_cfa88793c74dc2851a85d2d6101a5a11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto 2&lt;/div&gt;`)[0];
#                 popup_3920a2f7d339de6ab9ad9f5808f27182.setContent(html_cfa88793c74dc2851a85d2d6101a5a11);
#
#
#
#         marker_e6aa3be03e14cfa61bb4773a5fd07a4c.bindPopup(popup_3920a2f7d339de6ab9ad9f5808f27182)
#         ;
#
#
#
#
#             var marker_9310961c101281a0815f5cb4a3f638b0 = L.marker(
#                 [51.5074, -0.1278],
#                 {}
#             ).addTo(map_a393f5d9b982904589f5c176aa0b7816);
#
#
#             var icon_97f1610e2f0e2df399722fbddc729e69 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9310961c101281a0815f5cb4a3f638b0.setIcon(icon_97f1610e2f0e2df399722fbddc729e69);
#
#
#         var popup_f5b2086a0303af7246063305635bd14b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65d38795f9081319c2cf73853388544e = $(`&lt;div id=&quot;html_65d38795f9081319c2cf73853388544e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto 3&lt;/div&gt;`)[0];
#                 popup_f5b2086a0303af7246063305635bd14b.setContent(html_65d38795f9081319c2cf73853388544e);
#
#
#
#         marker_9310961c101281a0815f5cb4a3f638b0.bindPopup(popup_f5b2086a0303af7246063305635bd14b)
#         ;
#
#
#
#
#             var marker_b9d6902dacb04abcb473cf8427f26f35 = L.marker(
#                 [35.6895, 139.6917],
#                 {}
#             ).addTo(map_a393f5d9b982904589f5c176aa0b7816);
#
#
#             var icon_d949249f6e9b7aa28b5f5ed0c1db04e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quo

# %%
import folium
import pandas as pd

# Cargar los datos desde el archivo CSV
csv_path = "C:/Users/CFC/Downloads/INEGI_DENUE_31052024/INEGI_DENUE_31052024.csv"
df = pd.read_csv(csv_path, encoding='latin1')

# Asegurarse de que las columnas están correctamente nombradas
df = df.rename(columns={"Latitud": "lat", "Longitud": "long"})

# Crear un objeto de mapa centrado en la ubicación promedio de los puntos
mapa = folium.Map(location=[df['lat'].mean(), df['long'].mean()], zoom_start=5)

# Añadir puntos al mapa con información adicional
for _, row in df.iterrows():
    # Crear el contenido del popup con la información adicional
    popup_content = f"""
    <strong>Nombre:</strong> {row['Razon social']}<br>
    <strong>Dirección:</strong> {row['Numero de telefono']}<br>
    <strong>Actividad:</strong> {row['Sitio en Internet']}<br>
    <strong>Lat:</strong> {row['lat']}<br>
    <strong>Long:</strong> {row['long']}
    """
    folium.Marker(
        location=[row['lat'], row['long']],
        popup=folium.Popup(popup_content, max_width=300),
        icon=folium.Icon(icon="info-sign")
    ).add_to(mapa)

# Guardar el mapa en un archivo HTML
mapa.save("mapa.html")

# Mostrar el mapa en el entorno de Google Colab
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a226c2d3d5c8573d5da8f5943cfd6ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a226c2d3d5c8573d5da8f5943cfd6ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a226c2d3d5c8573d5da8f5943cfd6ee = L.map(
#                 &quot;map_5a226c2d3d5c8573d5da8f5943cfd6ee&quot;,
#                 {
#                     center: [19.360171144207495, -99.22189479976946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e255ae72152fb21f60fd7bb66c1ddba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3e255ae72152fb21f60fd7bb66c1ddba.addTo(map_5a226c2d3d5c8573d5da8f5943cfd6ee);
#
#             var marker_42bd60504c8a470dba5ded149758b48e = L.marker(
#                 [19.38216011, -99.24922099],
#                 {}
#             ).addTo(map_5a226c2d3d5c8573d5da8f5943cfd6ee);
#
#
#             var icon_4b510f9b291838b563928d1d856a282e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_42bd60504c8a470dba5ded149758b48e.setIcon(icon_4b510f9b291838b563928d1d856a282e);
#
#
#         var popup_5ef1e96513998cb6cbd2f6d008182622 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_a115fa3bff062208b678ed8532a747b1 = $(`&lt;div id=&quot;html_a115fa3bff062208b678ed8532a747b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Nombre:&lt;/strong&gt; nan&lt;br&gt;     &lt;strong&gt;Dirección:&lt;/strong&gt; nan&lt;br&gt;     &lt;strong&gt;Actividad:&lt;/strong&gt; nan&lt;br&gt;     &lt;strong&gt;Lat:&lt;/strong&gt; 19.38216011&lt;br&gt;     &lt;strong&gt;Long:&lt;/strong&gt; -99.24922099     &lt;/div&gt;`)[0];
#                 popup_5ef1e96513998cb6cbd2f6d008182622.setContent(html_a115fa3bff062208b678ed8532a747b1);
#
#
#
#         marker_42bd60504c8a470dba5ded149758b48e.bindPopup(popup_5ef1e96513998cb6cbd2f6d008182622)
#         ;
#
#
#
#
#             var marker_2094ccbd94b6ec818c664177b9550fe3 = L.marker(
#                 [19.32788841, -99.28363689],
#                 {}
#             ).addTo(map_5a226c2d3d5c8573d5da8f5943cfd6ee);
#
#
#             var icon_e92ea40fef6ae6e9c1b41d9d8fbd496c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2094ccbd94b6ec818c664177b9550fe3.setIcon(icon_e92ea40fef6ae6e9c1b41d9d8fbd496c);
#
#
#         var popup_b17702fe0a1a5e2a79705a5f7b0b07e4 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_65d62f45eddbb9d0aecef9ce206c5132 = $(`&lt;div id=&quot;html_65d62f45eddbb9d0aecef9ce206c5132&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Nombre:&lt;/strong&gt; nan&lt;br&gt;     &lt;strong&gt;Dirección:&lt;/strong&gt; nan&lt;br&gt;     &lt;strong&gt;Actividad:&lt;/strong&gt; nan&lt;br&gt;     &lt;strong&gt;Lat:&lt;/strong&gt; 19.32788841&lt;br&gt;     &lt;strong&gt;Long:&lt;/strong&gt; -99.28363689     &lt;/div&gt;`)[0];
#                 popup_b17702fe0a1a5e2a79705a5f7b0b07e4.setContent(html_65d62f45eddbb9d0aecef9ce206c5132);
#
#
#
#         marker_2094ccbd94b6ec818c664177b9550fe3.bindPopup(popup_b17702fe0a1a5e2a79705a5f7b0b07e4)
#         ;
#
#
#
#
#             var marker_f62fe9ff2da6c91bde4895b68543a13b = L.marker(
#                 [19.37170584, -99.23917687],
#                 {}
#             ).addTo(map_5a226c2d3d5c8573d5da8f5943cfd6ee);
#
#
#             var icon_887475ac9c961dbea0250c6e84074902 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f62fe9ff2da6c91bde4895b68543a13b.setIcon(icon_887475ac9c961dbea0250c6e84074902);
#
#
#         var popup_7a849f757e169563cf40e56f9d80bd28 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_0c5daeb55106fa1cc42d1322ec03b028 = $(`&lt;div id=&quot;html_0c5daeb55106fa1cc42d1322ec03b028&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Nombre:&lt;/strong&gt; nan&lt;br&gt

# %%
# !pip install geopandas folium

# %%
import geopandas as gpd
import folium

# Cargar el shapefile de los estados de México
gdf = gpd.read_file("path_to_shapefile/Mexico_Estados.shp")

# Crear un objeto de mapa centrado en México
m = folium.Map(location=[23.6345, -102.5528], zoom_start=5)

# Añadir los estados al mapa
folium.Choropleth(
    geo_data=gdf,
    name="choropleth",
    data=gdf,
    columns=["NOM_ENT", "CVE_ENT"],  # Reemplaza "NOM_ENT" y "CVE_ENT" con los nombres de las columnas en tu shapefile
    key_on="feature.properties.NOM_ENT",  # Reemplaza "NOM_ENT" con el nombre de la columna en tu shapefile
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Estados de México"
).add_to(m)

# Añadir una capa de control
folium.LayerControl().add_to(m)

# Guardar el mapa en un archivo HTML
m.save("mapa_mexico_estados.html")

# Mostrar el mapa en el entorno de Google Colab (si estás usando Colab)
m
